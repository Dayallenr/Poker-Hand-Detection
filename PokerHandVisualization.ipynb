# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('/best.pt')

# %%
results = model.predict('/IMG_5245.HEIC')
plotted = results[0].plot()
plt.imshow(cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# requirements: Ultralytics requirement ['pi-heif'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# image 1/1 /IMG_5245.HEIC: 480x640 2 4Cs, 2 6Cs, 2 6Ss, 2 9Hs, 2 ASs, 2292.8ms
# Speed: 23.4ms preprocess, 2292.8ms inference, 30.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].summary()
# Out:
# [{'name': '6C',
#   'class': 20,
#   'confidence': 0.7761,
#   'box': {'x1': 2319.07983,
#    'y1': 1353.52844,
#    'x2': 2466.68555,
#    'y2': 1645.99304}},
#  {'name': 'AS',
#   'class': 39,
#   'confidence': 0.76692,
#   'box': {'x1': 2022.91187,
#    'y1': 2312.32129,
#    'x2': 2171.75024,
#    'y2': 2621.93872}},
#  {'name': '4C',
#   'class': 12,
#   'confidence': 0.7635,
#   'box': {'x1': 3426.14136,
#    'y1': 1399.49487,
#    'x2': 3574.06738,
#    'y2': 1687.75403}},
#  {'name': '9H',
#   'class': 34,
#   'confidence': 0.75436,
#   'box': {'x1': 892.61383,
#    'y1': 2291.12939,
#    'x2': 1039.47437,
#    'y2': 2611.30396}},
#  {'name': '9H',
#   'class': 34,
#   'confidence': 0.73491,
#   'box': {'x1': 160.21417,
#    'y1': 1328.64197,
#    'x2': 310.70245,
#    'y2': 1627.00977}},
#  {'name': '6S',
#   'class': 23,
#   'confidence': 0.72671,
#   'box': {'x1': 4483.53809,
#    'y1': 1377.4447,
#    'x2': 4626.06934,
#    'y2': 1670.36597}},
#  {'name': '6C',
# ...

# %%
results = model.predict('/IMG_5246.HEIC')
plotted = results[0].plot()
plt.imshow(cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 /IMG_5246.HEIC: 480x640 4 10Hs, 1 7H, 2 AHs, 2 JHs, 1 KH, 1 QH, 2490.0ms
# Speed: 5.4ms preprocess, 2490.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].summary()
# Out:
# [{'name': '10H',
#   'class': 2,
#   'confidence': 0.76849,
#   'box': {'x1': 3145.32495,
#    'y1': 2276.12866,
#    'x2': 3295.00391,
#    'y2': 2574.12256}},
#  {'name': 'QH',
#   'class': 50,
#   'confidence': 0.76446,
#   'box': {'x1': 4284.53613,
#    'y1': 2304.15454,
#    'x2': 4446.49316,
#    'y2': 2616.53076}},
#  {'name': 'KH',
#   'class': 46,
#   'confidence': 0.74895,
#   'box': {'x1': 893.28687,
#    'y1': 2269.39331,
#    'x2': 1035.23352,
#    'y2': 2568.19946}},
#  {'name': '10H',
#   'class': 2,
#   'confidence': 0.74829,
#   'box': {'x1': 2364.23438,
#    'y1': 1271.76514,
#    'x2': 2509.14258,
#    'y2': 1543.82178}},
#  {'name': 'AH',
#   'class': 38,
#   'confidence': 0.71725,
#   'box': {'x1': 4599.74854,
#    'y1': 1351.31824,
#    'x2': 4742.76074,
#    'y2': 1629.91479}},
#  {'name': 'AH',
#   'class': 38,
#   'confidence': 0.70953,
#   'box': {'x1': 5456.16553,
#    'y1': 2365.55762,
#    'x2': 5590.47412,
#    'y2': 2649.86963}},
#  {'name': 'JH',
# ...

# %%
results = model.predict('/IMG_5247.HEIC')
plotted = results[0].plot()
plt.imshow(cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 /IMG_5247.HEIC: 480x640 2 10Ds, 2 10Ss, 2159.7ms
# Speed: 3.4ms preprocess, 2159.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].summary()
# Out:
# [{'name': '10S',
#   'class': 3,
#   'confidence': 0.80844,
#   'box': {'x1': 2118.55469,
#    'y1': 851.77026,
#    'x2': 2247.61426,
#    'y2': 1142.31775}},
#  {'name': '10D',
#   'class': 1,
#   'confidence': 0.8006,
#   'box': {'x1': 950.54858,
#    'y1': 890.44733,
#    'x2': 1070.22937,
#    'y2': 1172.16357}},
#  {'name': '10S',
#   'class': 3,
#   'confidence': 0.77476,
#   'box': {'x1': 2899.36841,
#    'y1': 1806.10828,
#    'x2': 3032.63208,
#    'y2': 2106.07397}},
#  {'name': '10D',
#   'class': 1,
#   'confidence': 0.75488,
#   'box': {'x1': 1741.46741,
#    'y1': 1831.43542,
#    'x2': 1869.79224,
#    'y2': 2121.92529}}]
